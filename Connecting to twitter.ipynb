# %% [markdown]
# # Connecting to Twitter

# %%
#Load required libraries
import os
import csv
import tweepy
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import codecs
import pymysql
import pandas as pd

# %%
#Store required keys
consumer_key =  "QCN4IFGoveD34zc1gyr6iJjPG"
consumer_secret ="Zyj8l6vp1YEvbFpflrZAQV3tIZM1BMvp1rYWYHPAbQtwKn39U8"  
access_key =  "2547528876-StORaF4ATwrLnuqMFEO9JzRANOePZ6VGiZbdahF"
access_secret = "zVm9j7vgaULQXh9ITosaAh8WryjczABLYmfG6SvyidLjJ"

# %%
#Establish connection
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)

# %%
#Extract tweets
#Create empty list
results = []

#Get the first 500 items based on the search query
for tweet in tweepy.Cursor(api.search, q = 'avengers').items(500):
    results.append(tweet)

# %%
 # Verify the number of items returned
    len(results)
# Out:
# 500

# %%
#Convert list into dataframe
def toDataFrame(tweets):
    #Create empty data frame
    DataSet = pd.DataFrame()
    
    #extract relevant information
    DataSet['tweetID'] = [tweet.id for tweet in tweets]
    DataSet['tweetText'] = [tweet.text for tweet in tweets]
    DataSet['tweetRetweetCt'] = [tweet.retweet_count for tweet in tweets]
    DataSet['tweetFavoriteCt'] = [tweet.favorite_count for tweet in tweets]
    DataSet['tweetSource'] = [tweet.source for tweet in tweets]
    DataSet['tweetCreated'] = [tweet.created_at for tweet in tweets]
    DataSet['userID'] = [tweet.user.id for tweet in tweets]
    DataSet['userScreen'] = [tweet.user.screen_name for tweet in tweets]
    DataSet['userName'] = [tweet.user.name for tweet in tweets]
    DataSet['userCreateDt'] = [tweet.user.created_at for tweet in tweets]
    DataSet['userDesc'] = [tweet.user.description for tweet in tweets]
    DataSet['userFollowerCt'] = [tweet.user.followers_count for tweet in tweets]
    DataSet['userFriendsCt'] = [tweet.user.friends_count for tweet in tweets]
    DataSet['userLocation'] = [tweet.user.location for tweet in tweets]
    DataSet['userTimezone'] = [tweet.user.time_zone for tweet in tweets]

    return DataSet

# %%
#Pass the tweets list to the above function to create a DataFrame
DataSet = toDataFrame(results)

# %%
DataSet.head()
# Out:
#                tweetID                                          tweetText  \
# 0  1207866360216346625  RT @mirmozebang: WHAT IF AVENGERS ENDGAME HAD ...
# 1  1207866284798435335  RT @marvelmex: Estos fanarts retratan las mejo...
# 2  1207866276405628928  RT @venusian_1: @TurboBurpo @brutalitybunny na...
# 3  1207866263076249600  RT @MCU_Direct: "Peggy never forgot about him....
# 4  1207866258655346688  RT @dhartist88: #WPMOYChallenge Rudolph #WPMOY...
#
#    tweetRetweetCt  tweetFavoriteCt          tweetSource        tweetCreated  \
# 0               1                0   Twitter for iPhone 2019-12-20 03:32:36
# 1              10                0  Twitter for Android 2019-12-20 03:32:18
# 2               1                0  Twitter for Android 2019-12-20 03:32:16
# 3             186                0  Twitter for Android 2019-12-20 03:32:12
# 4             146                0   Twitter for iPhone 2019-12-20 03:32:11
#
# ...

# %% [markdown]
# # sorting data

# %%
def sort(data, variable):
    data = data.sort_values(variable, ascending = False)
    
    return data

# %%
DataSet = sort(DataSet, 'tweetRetweetCt')

# %%
DataSet
# Out:
#                  tweetID                                          tweetText  \
# 375  1207858989641457664  RT @marvel_shots: AVENGERS!...Assemble https:/...
# 89   1207864453720662016  RT @marvel_shots: AVENGERS!...Assemble https:/...
# 297  1207860677282582528  RT @MrNiceGuy18_58: *Watches #AvengersEndgame ...
# 418  1207857953753194507  RT @MarveIFacts: 'Avengers... Assemble' https:...
# 464  1207856774008713217  RT @MarveIFacts: 'Avengers... Assemble' https:...
# 277  1207861105562918915  RT @nosabesnadajon: 3 cosas que se acabaron es...
# 104  1207864304202080257  RT @nosabesnadajon: 3 cosas que se acabaron es...
# 126  1207863889997766658  RT @nosabesnadajon: 3 cosas que se acabaron es...
# 256  1207861419716288513  RT @nosabesnadajon: 3 cosas que se acabaron es...
# 255  1207861424900444162  RT @nosabesnadajon: 3 cosas que se acabaron es...
# 36   1207865734921105409  RT @nosabesnadajon: 3 cosas que se acabaron es...
# ...
